# %%
import pandas as pd

df0=pd.read_csv("exp123_page1.csv", encoding='utf8')
df1=pd.read_csv("exp123_page2.csv", encoding='utf8')

#df.head

# %%
title = ['F1','F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11', 'F12', 'F13', 'M1', 'M2', 'M3', 
         'M5', 'M6', 'M7','M8', 'M9']

for index, row in df1.iterrows():
    for t in title:
        f1ans = row[t].strip().split('-')
        ans2 = [a.split(' ') for a in f1ans]
        ans = [item for sublist in ans2 for item in sublist]
        if (len(ans) != 16):
            print('[', t, index + 2, ']', len(ans), ans)
# Out:
# [ M2 13 ] 20 ['i', '51', 'lu', '51', 'liŋ', '51', 'ly', '51', 'li', '51', 'ly', '51', 'ly', '51', 'ly', '51', 'li', '51', 'lu', '51']

# %%
title = ['F1','F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11', 'F12', 'F13', 'M1', 'M2', 'M3', 
         'M5', 'M6', 'M7','M8', 'M9']
phoneme=[]
vowel=['i', 'y', 'e', 'ɛ',  'a', 'ɨ', 'ə', 'u', 'o', 'ɔ', 'ɤ']
consonent=['p', 'pʰ', 'm', 'f', 't', 'tʰ', 'n', 'l', 's', 'ʂ', 'ʐ', 'ts', 'tsʰ', 'tʂ', 'tʂʰ', 'ɕ', 'tɕ', 'tɕʰ', 'k', 'kʰ',    
           'ŋ',  'x', 'j', 'ɥ', 'w']
fsound=['51','55','35','21', 'y']
phoneme = vowel + consonent
sorted_phoneme = sorted(phoneme, key=len, reverse=True)
#sorted_phoneme.remove('x')
#sorted_phoneme.append('x')
sorted_phoneme.append('_')

print(consonent, vowel)
print(sorted_phoneme)
# Out:
# ['p', 'pʰ', 'm', 'f', 't', 'tʰ', 'n', 'l', 's', 'ʂ', 'ʐ', 'ts', 'tsʰ', 'tʂ', 'tʂʰ', 'ɕ', 'tɕ', 'tɕʰ', 'k', 'kʰ', 'ŋ', 'x', 'j', 'ɥ', 'w'] ['i', 'y', 'e', 'ɛ', 'a', 'ɨ', 'ə', 'u', 'o', 'ɔ', 'ɤ']
# ['tsʰ', 'tʂʰ', 'tɕʰ', 'pʰ', 'tʰ', 'ts', 'tʂ', 'tɕ', 'kʰ', 'i', 'y', 'e', 'ɛ', 'a', 'ɨ', 'ə', 'u', 'o', 'ɔ', 'ɤ', 'p', 'm', 'f', 't', 'n', 'l', 's', 'ʂ', 'ʐ', 'ɕ', 'k', 'ŋ', 'x', 'j', 'ɥ', 'w', '_']

# %%
fsconf = pd.DataFrame(0, columns=fsound, index=fsound)

print(fsconf)
# Out:
#     51  55  35  21  y
# 51   0   0   0   0  0
# 55   0   0   0   0  0
# 35   0   0   0   0  0
# 21   0   0   0   0  0
# y    0   0   0   0  0

# %%
def phoneme_analysis(item):
    #print(item)
    if item == '':
        return []
    
    for i in sorted_phoneme:
        if item.find(i) == 0:
            #print("Match", i)
            sl=[i]
            srl=phoneme_analysis(item[len(i):])
            if srl is None:
                print("No match", item)
                return sl
            else:
                return(sl+srl)

# %%
def LD(s, t):
    if s == "":
        return len(t)
    if t == "":
        return len(s)
    if s[-1] == t[-1]:
        cost = 0
    else:
        cost = 1
       
    res = min([LD(s[:-1], t)+1,
               LD(s, t[:-1])+1, 
               LD(s[:-1], t[:-1]) + cost])

    return res

print(LD("Python", "Peithen"))
# Out:
# 3

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

def plot_conf(conconf, vowconf):
    plt.figure(figsize = (15,12))
    sn.heatmap(conconf, annot=True, fmt="d", cmap="YlGnBu")
    plt.xlabel('Target', fontsize = 15) # x-axis label with fontsize 15
    plt.ylabel('Response', fontsize = 15)
    
    plt.figure(figsize=(15,12))
    sn.heatmap(vowconf, annot=True, fmt="d", cmap="YlGnBu")
    plt.xlabel('Target', fontsize = 15) # x-axis label with fontsize 15
    plt.ylabel('Response', fontsize = 15)

# %%
#sorted_consonent = sorted(consonent, key=len, reverse=True)
#print(sorted_consonent)

#conconf = pd.DataFrame(0, columns=consonent, index=consonent[::-1])
#vowconf = pd.DataFrame(0, columns=vowel, index=vowel[::-1])

#print(pnconf)

def split_items(val):
    ans = []
    for t in target:
        tl = t.split('-')
        ttl = [x.split(' ') for x in tl]
        ans.append(ttl)
    return ans

def phoneme_calc(df):
    conconf = pd.DataFrame(0, columns=consonent, index=consonent[::-1])
    vowconf = pd.DataFrame(0, columns=vowel, index=vowel[::-1])

    tg = df['Target'].to_list()
    #print("Target", tg)


    for t in title:
        #print(t)
        ans = df[t].to_list()
        idx = 1
        for it, ia in zip(tg, ans):
            idx = idx + 1
            lit = it.split('-')
            lia = ia.split('-')
            for ilit, ilia in zip(lit, lia):
                ts= ilit.split(' ')
                xs = ilia.split(' ')
                for its, ixs in zip(ts, xs):
                    if its in fsound and ixs in fsound:
                        fsconf.loc[its][ixs] =fsconf.loc[its][ixs]+1
                    else:
                        lits = phoneme_analysis(its)
                        lixs = phoneme_analysis(ixs)

                        if len(lits) != len(lixs):
                            break;
    #                        lixs.extend(['_'] * (len(lits)-len(lixs)))
    #                    elif len(lits) < len(lixs):
    #                        lits.extend(['_'] * (len(lixs)-len(lits)))
                        else:
                            #print(lits, lixs)
                            for ilits, ilixs in zip(lits, lixs):
                                if ilixs == 'x':
                                    break
                                elif ilits != ilixs:
                                    #print("Diff[", t, idx, ']', ilits, ilixs)
                                    if ilits in consonent and ilixs in consonent:
                                        conconf.loc[ilits][ilixs] = conconf.loc[ilits][ilixs] +1
                                    elif ilits in vowel and ilixs in vowel:
                                        vowconf.loc[ilits][ilixs] = vowconf.loc[ilits][ilixs] +1
                                    else:
                                        print("location: [", t, idx, "], Error in matching", ilits, ilixs, lits, lixs)
                                        print(its, ixs)
                                        print(LD(its, ixs))
                                else:
                                    if ilits in consonent:
                                        conconf.loc[ilits][ilixs] = conconf.loc[ilits][ilixs] +1
                                    elif ilits in vowel:
                                        vowconf.loc[ilits][ilixs] = vowconf.loc[ilits][ilixs] +1
                                    else:
                                        print("Unknown match")
                                        
    return conconf, vowconf
                                        
c, v = phoneme_calc(df0)
plot_conf(c,v)
print("----")
c, v =phoneme_calc(df1)
plot_conf(c,v)
# Out:
# location: [ F4 11 ], Error in matching l a ['l', 'a'] ['a', 'n']
# la an
# 2
# location: [ F4 11 ], Error in matching a n ['l', 'a'] ['a', 'n']
# la an
# 2
# location: [ F5 11 ], Error in matching a w ['l', 'a', 'w'] ['l', 'w', 'ɔ']
# law lwɔ
# 2
# location: [ F5 11 ], Error in matching w ɔ ['l', 'a', 'w'] ['l', 'w', 'ɔ']
# law lwɔ
# 2
# location: [ F9 21 ], Error in matching a j ['ʂ', 'a', 'w'] ['tɕ', 'j', 'ɛ']
# ʂaw tɕjɛ
# 4
# location: [ F9 21 ], Error in matching w ɛ ['ʂ', 'a', 'w'] ['tɕ', 'j', 'ɛ']
# ʂaw tɕjɛ
# 4
# location: [ F11 11 ], Error in matching a w ['l', 'a', 'w'] ['l', 'w', 'ɔ']
# law lwɔ
# 2
# location: [ F11 11 ], Error in matching w ɔ ['l', 'a', 'w'] ['l', 'w', 'ɔ']
# law lwɔ
# 2
# location: [ M5 19 ], Error in matching a w ['tʂ', 'a', 'w'] ['k', 'w', 'ɔ']
# tʂaw kwɔ
# 4
# location: [ M5 19 ], Error in matching w ɔ ['tʂ', 'a', 'w'] ['k', 'w', 'ɔ']
# tʂaw kwɔ
# 4
# location: [ M6 26 ], Error in matching a j ['ts', 'a', 'n'] ['tɕ', 'j', 'ɛ']
# tsan tɕjɛ
# 3
# location: [ M6 26 ], Error in matching n ɛ ['ts', 'a', 'n'] ['tɕ', 'j', 'ɛ']
# tsan tɕjɛ
# 3
# location: [ M7 19 ], Error in matching a w ['tʂ', 'a', 'n'] ['tʂ', 'w', 'ɔ']
# tʂan tʂwɔ
# 2
# location: [ M7 19 ], Error in matching n ɔ ['tʂ', 'a', 'n'] ['tʂ', 'w', 'ɔ']
# tʂan tʂwɔ
# 2
# No match sɑn
# ----
# location: [ F1 6 ], Error in matching a t ['a', 'j'] ['t', 'a']
# aj ta
# 2
# location: [ F1 6 ], Error in matching j a ['a', 'j'] ['t', 'a']
# aj ta
# 2
# location: [ F2 3 ], Error in matching ə s ['ə', 'n'] ['s', 'i']
# ən si
# 2
# location: [ F2 3 ], Error in matching n i ['ə', 'n'] ['s', 'i']
# ən si
# 2
# location: [ F2 7 ], Error in matching tʰ o ['tʰ', 'a'] ['o', 'w']
# tʰa ow
# 3
# location: [ F2 7 ], Error in matching a w ['tʰ', 'a'] ['o', 'w']
# tʰa ow
# 3
# location: [ F2 10 ], Error in matching ts a ['ts', 'ɨ'] ['a', 'n']
# tsɨ an
# 3
# location: [ F2 10 ], Error in matching ɨ n ['ts', 'ɨ'] ['a', 'n']
# tsɨ an
# 3
# location: [ F2 10 ], Error in matching tsʰ a ['tsʰ', 'ɨ'] ['a', 'n']
# tsʰɨ an
# 4
# location: [ F2 10 ], Error in matching ɨ n ['tsʰ', 'ɨ'] ['a', 'n']
# tsʰɨ an
# 4
# location: [ F3 18 ], Error in matching a j ['a', 'ŋ'] ['j', 'a']
# aŋ ja
# 2
# location: [ F3 18 ], Error in matching ŋ a ['a', 'ŋ'] ['j', 'a']
# aŋ ja
# 2
# location: [ F4 16 ], Error in matching a p ['a', 'n'] ['p', 'a']
# an pa
# 2
# location: [ F4 16 ], Error in matching n a ['a', 'n'] ['p', 'a']
# an pa
# 2
# location: [ F5 13 ], Error in matching l i ['l', 'i'] ['i', 'n']
# li in
# 2
# location: [ F5 13 ], Error in matching i n ['l', 'i'] ['i', 'n']
# li in
# 2
# location: [ F6 18 ], Error in matching o w ['t', 'o', 'ŋ'] ['t', 'w', 'ɔ']
# toŋ twɔ
# 2
# location: [ F6 18 ], Error in matching ŋ ɔ ['t', 'o', 'ŋ'] ['t', 'w', 'ɔ']
# toŋ twɔ
# 2
# location: [ F7 16 ], Error in matching i j ['i', 'ŋ'] ['j', 'a']
# iŋ ja
# 2
# location: [ F7 16 ], Error in matching ŋ a ['i', 'ŋ'] ['j', 'a']
# iŋ ja
# 2
# location: [ F7 18 ], Error in matching a j ['a', 'ŋ'] ['j', 'a']
# aŋ ja
# 2
# location: [ F7 18 ], Error in matching ŋ a ['a', 'ŋ'] ['j', 'a']
# aŋ ja
# 2
# location: [ F8 13 ], Error in matching i l ['i', 'ŋ'] ['l', 'i']
# iŋ li
# 2
# location: [ F8 13 ], Error in matching ŋ i ['i', 'ŋ'] ['l', 'i']
# iŋ li
# 2
# location: [ F10 12 ], Error in matching s ə ['s', 'ɨ'] ['ə', 'n']
# sɨ ən
# 2
# location: [ F10 12 ], Error in matching ɨ n ['s', 'ɨ'] ['ə', 'n']
# sɨ ən
# 2
# location: [ F11 18 ], Error in matching o w ['o', 'ŋ'] ['w', 'a']
# oŋ wa
# 2
# location: [ F11 18 ], Error in matching ŋ a ['o', 'ŋ'] ['w', 'a']
# oŋ wa
# 2
# location: [ F12 4 ], Error in matching w a ['w', 'a'] ['a', 'n']
# wa an
# 2
# location: [ F12 4 ], Error in matching a n ['w', 'a'] ['a', 'n']
# wa an
# 2
# location: [ F12 13 ], Error in matching i l ['i', 'ŋ'] ['l', 'y']
# iŋ ly
# 2
# location: [ F12 13 ], Error in matching ŋ y ['i', 'ŋ'] ['l', 'y']
# iŋ ly
# 2
# location: [ F13 13 ], Error in matching i l ['i', 'ŋ'] ['l', 'y']
# iŋ ly
# 2
# location: [ F13 13 ], Error in matching ŋ y ['i', 'ŋ'] ['l', 'y']
# iŋ ly
# 2
# location: [ M1 10 ], Error in matching ts a ['ts', 'a'] ['a', 'n']
# tsa an
# 3
# location: [ M1 10 ], Error in matching a n ['ts', 'a'] ['a', 'n']
# tsa an
# 3
# location: [ M1 12 ], Error in matching tsʰ ə ['tsʰ', 'ɨ'] ['ə', 'n']
# tsʰɨ ən
# 4
# location: [ M1 12 ], Error in matching ɨ n ['tsʰ', 'ɨ'] ['ə', 'n']
# tsʰɨ ən
# 4
# location: [ M1 13 ], Error in matching l i ['l', 'y'] ['i', 'n']
# ly in
# 2
# location: [ M1 13 ], Error in matching y n ['l', 'y'] ['i', 'n']
# ly in
# 2
# location: [ M1 14 ], Error in matching tʰ i ['tʰ', 'u'] ['i', 'n']
# tʰu in
# 3
# location: [ M1 14 ], Error in matching u n ['tʰ', 'u'] ['i', 'n']
# tʰu in
# 3
# location: [ M2 2 ], Error in matching o tʂ ['o', 'ŋ'] ['tʂ', 'a']
# oŋ tʂa
# 3
# location: [ M2 2 ], Error in matching ŋ a ['o', 'ŋ'] ['tʂ', 'a']
# oŋ tʂa
# 3
# location: [ M2 13 ], Error in matching i l ['i', 'ŋ'] ['l', 'y']
# iŋ ly
# 2
# location: [ M2 13 ], Error in matching ŋ y ['i', 'ŋ'] ['l', 'y']
# iŋ ly
# 2
# location: [ M3 13 ], Error in matching i l ['i', 'ŋ'] ['l', 'i']
# iŋ li
# 2
# location: [ M3 13 ], Error in matching ŋ i ['i', 'ŋ'] ['l', 'i']
# iŋ li
# 2
# location: [ M5 6 ], Error in matching a w ['t', 'a', 'j'] ['t', 'w', 'ɔ']
# taj twɔ
# 2
# location: [ M5 6 ], Error in matching j ɔ ['t', 'a', 'j'] ['t', 'w', 'ɔ']
# taj twɔ
# 2
# location: [ M5 13 ], Error in matching i l ['i', 'ŋ'] ['l', 'u']
# iŋ lu
# 2
# location: [ M5 13 ], Error in matching ŋ u ['i', 'ŋ'] ['l', 'u']
# iŋ lu
# 2
# location: [ M5 16 ], Error in matching a j ['a', 'n'] ['j', 'a']
# an ja
# 2
# location: [ M5 16 ], Error in matching n a ['a', 'n'] ['j', 'a']
# an ja
# 2
# location: [ M6 7 ], Error in matching o pʰ ['o', 'w'] ['pʰ', 'ɔ']
# ow pʰɔ
# 3
# location: [ M6 7 ], Error in matching w ɔ ['o', 'w'] ['pʰ', 'ɔ']
# ow pʰɔ
# 3
# location: [ M6 13 ], Error in matching i l ['i', 'ŋ'] ['l', 'i']
# iŋ li
# 2
# location: [ M6 13 ], Error in matching ŋ i ['i', 'ŋ'] ['l', 'i']
# iŋ li
# 2
# location: [ M7 2 ], Error in matching o w ['o', 'ŋ'] ['w', 'a']
# oŋ wa
# 2
# location: [ M7 2 ], Error in matching ŋ a ['o', 'ŋ'] ['w', 'a']
# oŋ wa
# 2
# location: [ M7 2 ], Error in matching o w ['o', 'ŋ'] ['w', 'a']
# oŋ wa
# 2
# location: [ M7 2 ], Error in matching ŋ a ['o', 'ŋ'] ['w', 'a']
# oŋ wa
# 2
# location: [ M7 4 ], Error in matching a w ['a', 'n'] ['w', 'a']
# an wa
# 2
# location: [ M7 4 ], Error in matching n a ['a', 'n'] ['w', 'a']
# an wa
# 2
# location: [ M7 13 ], Error in matching i l ['i', 'ŋ'] ['l', 'y']
# iŋ ly
# 2
# location: [ M7 13 ], Error in matching ŋ y ['i', 'ŋ'] ['l', 'y']
# iŋ ly
# 2
# location: [ M7 16 ], Error in matching a p ['a', 'n'] ['p', 'a']
# an pa
# 2
# location: [ M7 16 ], Error in matching n a ['a', 'n'] ['p', 'a']
# an pa
# 2
# location: [ M9 13 ], Error in matching l i ['l', 'y'] ['i', 'ŋ']
# ly iŋ
# 2
# location: [ M9 13 ], Error in matching y ŋ ['l', 'y'] ['i', 'ŋ']
# ly iŋ
# 2
# location: [ M9 13 ], Error in matching i l ['i', 'ŋ'] ['l', 'i']
# iŋ li
# 2
# location: [ M9 13 ], Error in matching ŋ i ['i', 'ŋ'] ['l', 'i']
# iŋ li
# 2

# %%
print(ts, xs, lits, lixs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2292a8df0940> in <module>
# ----> 1 print(ts, xs, lits, lixs)
#
# NameError: name 'ts' is not defined

# %%
for (columnName, columnData) in df0.iteritems():
    if columnName == 'Target':
        target = columnData.values
        targetlist = split_items(target)
        #print(targetlist)
    elif columnName == '測試項目':
        continue
    else:
        print(columnName)
        tstr=columnName
        tstrans = columnData.values
        anslist = split_items(tstrans)
        #print(anslist)
        
        for t, a in zip(targetlist, anslist):
            for it, ia in zip(t, a):
                for tit, aia in zip(it, ia):
                    #if tit != aia:
                    print("Target=", tit, "Ans=", aia)
                
        
            
            #fttl = [val for sublist in tl for val in sublist]
        #ans = target.strip().replace(' ','-').split('-')
        #print(ans)
#    print('Colunm Name : ', columnName)
#    print('Column Contents : ', columnData.values)

# %%
print(index)

# %%
#x=phoneme_analysis('waŋ')
#print(x)
 
xx = "wən  pəŋ  oŋ  pən  wən  toŋ  oŋ  təŋ in  pən  ən  pin  in  təŋ  wən  tiŋ u  pʰa  wa  pʰu  u  tʰan  an  tʰu iŋ  lɤ  ɤ liŋ  i  tʰɤ  ɤ  tʰi an  paŋ  aŋ  pan  aj  taw  aw  taj ow  pʰan  an  pʰow  ow  tʰa  a  tʰow wej  paj  aj  pej  wej  tan  an  twej i  pʰu  u  pʰi  i  tʰu  u  tʰi tsɨ  tsʰa  tsa  tsʰɨ  tsɨ  sa  tsa  sɨ y  lu  u  ly  ly  u  lu  y tsu  tsʰɨ  tsɨ  tsʰu  tsu  sɨ  tsɨ  su i  ly  y  li  liŋ  y  ly  iŋ u  lɤ  ɤ  lu  u  tʰɤ  ɤ  tʰu y  la  ja  ly  ly  ja  la  y i  pa  ja  pi  iŋ  tan  an  tiŋ y  lɤ  ɤ ly  ly  ɤ  lɤ  y jow  paw  aŋ  pəŋ  oŋ  taŋ  waŋ  toŋ tsɨ  tsʰɤ  tsɤ  tsʰɨ  tsɨ  sɤ  tsɤ  sɨ"

xxx = xx.replace('  ', ' ')
xlist = xxx.split(' ')
#print(xlist)

for x in xlist:
    print(x, end=' ')
    xp = phoneme_analysis(x)
    print(xp)

# %%
import numpy as np

count = 0
df1len=28
df2len=19
cres = pd.DataFrame(0, index=np.arange(start=1, stop=df1len), columns=title)
vres = pd.DataFrame(0, index=np.arange(start=1, stop=df1len), columns=title)
fres = pd.DataFrame(0, index=np.arange(start=1, stop=df1len), columns=title)
cres.head

# %%
for t in title:
    for index, row in df1.iterrows():
        ans = row['Target'].strip().replace(' ','-').split('-')
        print('ANS=', ans)
        print('Row', index+2, ' ------------------------------------')
        for t in title:
            f1ans = row[t].strip().replace(' ','-').split('-')
            print(t, end = " ")
            for a, b in zip(ans, f1ans):
                if a != b:
                    print('[',a, b,']', end=" ")
                    if b == 'x':
                        count = count + 1
            print()
        
print(count)
