# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import pandas as pd

#zdf = pd.DataFrame()
SPECZ1=['ㄓ','ㄔ','ㄕ','ㄖ','ㄗ','ㄘ','ㄙ']
SPECZ2=['ㄧ','ㄨ','ㄩ']
CSPECZ2=['i','u','y']
FOURSOUNDS=['ˊ','ˇ','ˋ','˙']
DUOZ=['ㄧㄢ','ㄩㄢ','ㄧㄣ','ㄧㄥ','ㄨㄥ','ㄩㄥ']

def read_zhuyin2ipa_table():
    zdf = pd.read_excel("zhuyin2ipa.xlsx")
    #print(zdf)
    return zdf

def is_ascii(check_str):
     return all(ord(c) < 128 for c in check_str)

def foursounds(c):
    if 'ˋ' in c:
        return "51 "
    elif 'ˊ' in c:
        return "35 "
    elif 'ˇ' in c:
        return "21 "
    elif '˙' in c:
        return "0 "
    else:
        return "55 "
    
def convertZH(zdf, zh):
    '''This function checks the Zhuyin table and return corresponding
       IPA, 
       return '' if not found
       return IPA element in the table with leading and tailing space
              stripped
    '''
    #print("searching", zh)
    x = zdf[zdf['Zhuyin']==zh].IPA.to_string(index=False)
    if x == "Series([], )":
        return ''
    else:
        #return x.replace(' ','')
        return x.rstrip().lstrip().replace('\n','')

def convertZHL(zdf, zh):
    s = convertZH(zdf, zh)
    if s == '':
        return []
    else:
        return s.split(' ')
    
def remove_foursounds(zh):
    z = zh
    for f in FOURSOUNDS:
        z = z.replace(f,'')
    return z

def is_duo(zh):
    for d in DUOZ:
        if d in zh:
            return True
    return False

def duo_convert(zdf, zh):
    #print("zh0",zh[0])
    matching = False
    for z in SPECZ2:
        #print("zzh", z, zh[0])
        if z == zh[0]:
            matching = True
            break
    
    if matching:
        #print("Converting zh", zh)
        return convertZHL(zdf, zh)
    else:
        lead = convertZHL(zdf, zh[0])
        trail = convertZHL(zdf, zh[1:])
        print(lead, trail)
        return lead.append(trail)
    
def convertIUY(z):
    if z == 'ㄧ':
        return 'i'
    elif z == 'ㄨ':
        return 'u'
    else:
        return 'y'
    
def toipa(zdf, zhuyin):
    zh=remove_foursounds(zhuyin)
    idx = 0
    zhlen = len(zh)
    
    if is_duo(zh):
        return(duo_convert(zdf, zh))
    
    IPAL=[]
    while (idx < zhlen):
        #print(idx)
        if zh[idx] in SPECZ1:
            if zhlen == 1:
                return ([convertZHL(zdf, zh[idx]), ['ɨ']])
            else:
                IPAL.append(convertZHL(zdf, zh[idx]))
                idx = idx + 1
                
        elif zh[idx] in SPECZ2:
            if idx == zhlen - 1:
                #The last one
                lc = [convertIUY(zh[idx])]
                IPAL.append(lc)
                return IPAL
            else:
                IPAL.append(convertZHL(zdf, zh[idx]))
                idx = idx + 1
        else:
            IPAL.append(convertZHL(zdf, zh[idx]))
            idx = idx + 1
            
    #print(IPAL)
    return IPAL

# %%
def read_dict():
    # to read just one sheet to dataframe:
    df = pd.read_excel('cdict_cond.xlsx')
    return(df)

# %%
def zhuyin2ipa(ddf, zdf):
    for index, row in ddf.iterrows():
        phlist = row['phone'].split('　')
        for p in phlist:
            pipa = toipa(zdf, p)
            print(p, pipa, end=" ")
        print()

# %%
zdf = read_zhuyin2ipa_table()

# %%
ddf = read_dict()

# %%
#print(toipa(zdf, 'ㄆㄧㄠ'))
zhuyin2ipa(ddf,zdf)
#print(zdf.head)
#print(ddf.head)

def main():
    return

if __name__ == '__main__':
    main()  # 或是任何你想執行的函式
# Out:
# ㄅㄚ [['p'], ['a']]
# ㄅㄚ [['p'], ['a']]
# ㄅㄚ [['p'], ['a']]
# ㄅㄚ [['p'], ['a']]
# ㄅㄚ [['p'], ['a']]
# ㄅㄚ [['p'], ['a']]
# ㄅㄚ [['p'], ['a']]
# ㄅㄚ [['p'], ['a']]
# ㄅㄚ [['p'], ['a']]
# ㄅㄚ [['p'], ['a']]
# ㄅㄚ [['p'], ['a']]
# ㄅㄚ [['p'], ['a']]
# ㄅㄚ [['p'], ['a']]
# ㄅㄚˊ [['p'], ['a']]
# ㄅㄚˊ [['p'], ['a']]
# ㄅㄚˊ [['p'], ['a']]
# ㄅㄚˊ [['p'], ['a']]
# ㄅㄚˊ [['p'], ['a']]
# ㄅㄚˊ [['p'], ['a']]
# ㄅㄚˊ [['p'], ['a']]
# ㄅㄚˊ [['p'], ['a']]
# ㄅㄚˊ [['p'], ['a']]
# ㄅㄚˇ [['p'], ['a']]
# ㄅㄚˇ [['p'], ['a']]
# ㄅㄚˇ [['p'], ['a']]
# ㄅㄚˋ [['p'], ['a']]
# ㄅㄚˋ [['p'], ['a']]
# ㄅㄚˋ [['p'], ['a']]
# ㄅㄚˋ [['p'], ['a']]
# ㄅㄚˋ [['p'], ['a']]
# ㄅㄚˋ [['p'], ['a']]
# ㄅㄚˋ [['p'], ['a']]
# ㄅㄚˋ [['p'], ['a']]
# ㄅㄚˋ [['p'], ['a']]
# ㄅㄚˋ [['p'], ['a']]
# ˙ㄅㄚ [['p'], ['a']]
# ˙ㄅㄚ [['p'], ['a']]
# ˙ㄅㄚ [['p'], ['a']]
# ˙ㄅㄚ [['p'], ['a']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˊ [['p'], ['ɔ']]
# ㄅㄛˇ [['p'], ['ɔ']]
# ㄅㄛˇ [['p'], ['ɔ']]
# ㄅㄛˋ [['p'], ['ɔ']]
# ㄅㄛˋ [['p'], ['ɔ']]
# ㄅㄛˋ [['p'], ['ɔ']]
# ㄅㄛˋ [['p'], ['ɔ']]
# ㄅㄛˋ [['p'], ['ɔ']]
# ㄅㄛˋ [['p'], ['ɔ']]
# ㄅㄛˋ [['p'], ['ɔ']]
# ㄅㄛˋ [['p'], ['ɔ']]
# ㄅㄛˋ [['p'], ['ɔ']]
# ㄅㄛˋ [['p'], ['ɔ']]
# ˙ㄅㄛ [['p'], ['ɔ']]
# ˙ㄅㄛ [['p'], ['ɔ']]
# ㄅㄞ [['p'], ['a', 'j']]
# ㄅㄞˊ [['p'], ['a', 'j']]
# ㄅㄞˇ [['p'], ['a', 'j']]
# ㄅㄞˇ [['p'], ['a', 'j']]
# ㄅㄞˇ [['p'], ['a', 'j']]
# ㄅㄞˇ [['p'], ['a', 'j']]
# ㄅㄞˇ [['p'], ['a', 'j']]
# ㄅㄞˇ [['p'], ['a', 'j']]
# ㄅㄞˇ [['p'], ['a', 'j']]
# ㄅㄞˇ [['p'], ['a', 'j']]
# ㄅㄞˋ [['p'], ['a', 'j']]
# ㄅㄞˋ [['p'], ['a', 'j']]
# ㄅㄞˋ [['p'], ['a', 'j']]
# ㄅㄞˋ [['p'], ['a', 'j']]
# ㄅㄞˋ [['p'], ['a', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄟˇ [['p'], ['e', 'j']]
# ㄅㄟˇ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄟˋ [['p'], ['e', 'j']]
# ˙ㄅㄟ [['p'], ['e', 'j']]
# ㄅㄠ [['p'], ['a', 'w']]
# ㄅㄠ [['p'], ['a', 'w']]
# ㄅㄠ [['p'], ['a', 'w']]
# ㄅㄠ [['p'], ['a', 'w']]
# ㄅㄠ [['p'], ['a', 'w']]
# ㄅㄠ [['p'], ['a', 'w']]
# ㄅㄠ [['p'], ['a', 'w']]
# ㄅㄠ [['p'], ['a', 'w']]
# ㄅㄠ [['p'], ['a', 'w']]
# ㄅㄠ [['p'], ['a', 'w']]
# ㄅㄠ [['p'], ['a', 'w']]
# ㄅㄠ [['p'], ['a', 'w']]
# ㄅㄠˊ [['p'], ['a', 'w']]
# ㄅㄠˊ [['p'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']]
# ㄅㄢ [['p'], ['a', 'n']]
# ㄅㄢ [['p'], ['a', 'n']]
# ㄅㄢ [['p'], ['a', 'n']]
# ㄅㄢ [['p'], ['a', 'n']]
# ㄅㄢ [['p'], ['a', 'n']]
# ㄅㄢ [['p'], ['a', 'n']]
# ㄅㄢ [['p'], ['a', 'n']]
# ㄅㄢ [['p'], ['a', 'n']]
# ㄅㄢ [['p'], ['a', 'n']]
# ㄅㄢˇ [['p'], ['a', 'n']]
# ㄅㄢˇ [['p'], ['a', 'n']]
# ㄅㄢˇ [['p'], ['a', 'n']]
# ㄅㄢˇ [['p'], ['a', 'n']]
# ㄅㄢˇ [['p'], ['a', 'n']]
# ㄅㄢˇ [['p'], ['a', 'n']]
# ㄅㄢˇ [['p'], ['a', 'n']]
# ㄅㄢˇ [['p'], ['a', 'n']]
# ㄅㄢˇ [['p'], ['a', 'n']]
# ㄅㄢˇ [['p'], ['a', 'n']]
# ㄅㄢˋ [['p'], ['a', 'n']]
# ㄅㄢˋ [['p'], ['a', 'n']]
# ㄅㄢˋ [['p'], ['a', 'n']]
# ㄅㄢˋ [['p'], ['a', 'n']]
# ㄅㄢˋ [['p'], ['a', 'n']]
# ㄅㄢˋ [['p'], ['a', 'n']]
# ㄅㄢˋ [['p'], ['a', 'n']]
# ㄅㄢˋ [['p'], ['a', 'n']]
# ㄅㄢˋ [['p'], ['a', 'n']]
# ㄅㄣ [['p'], ['ə', 'n']]
# ㄅㄣ [['p'], ['ə', 'n']]
# ㄅㄣ [['p'], ['ə', 'n']]
# ㄅㄣˇ [['p'], ['ə', 'n']]
# ㄅㄣˇ [['p'], ['ə', 'n']]
# ㄅㄣˇ [['p'], ['ə', 'n']]
# ㄅㄣˋ [['p'], ['ə', 'n']]
# ㄅㄣˋ [['p'], ['ə', 'n']]
# ㄅㄣˋ [['p'], ['ə', 'n']]
# ㄅㄣˋ [['p'], ['ə', 'n']]
# ㄅㄤ [['p'], ['a', 'ŋ']]
# ㄅㄤ [['p'], ['a', 'ŋ']]
# ㄅㄤ [['p'], ['a', 'ŋ']]
# ㄅㄤ [['p'], ['a', 'ŋ']]
# ㄅㄤˇ [['p'], ['a', 'ŋ']]
# ㄅㄤˇ [['p'], ['a', 'ŋ']]
# ㄅㄤˇ [['p'], ['a', 'ŋ']]
# ㄅㄤˇ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄤˋ [['p'], ['a', 'ŋ']]
# ㄅㄥ [['p'], ['ə', 'ŋ']]
# ㄅㄥ [['p'], ['ə', 'ŋ']]
# ㄅㄥ [['p'], ['ə', 'ŋ']]
# ㄅㄥ [['p'], ['ə', 'ŋ']]
# ㄅㄥ [['p'], ['ə', 'ŋ']]
# ㄅㄥˊ [['p'], ['ə', 'ŋ']]
# ㄅㄥˇ [['p'], ['ə', 'ŋ']]
# ㄅㄥˇ [['p'], ['ə', 'ŋ']]
# ㄅㄥˇ [['p'], ['ə', 'ŋ']]
# ㄅㄥˋ [['p'], ['ə', 'ŋ']]
# ㄅㄥˋ [['p'], ['ə', 'ŋ']]
# ㄅㄥˋ [['p'], ['ə', 'ŋ']]
# ㄅㄥˋ [['p'], ['ə', 'ŋ']]
# ㄅㄥˋ [['p'], ['ə', 'ŋ']]
# ㄅㄥˋ [['p'], ['ə', 'ŋ']]
# ㄅㄥˋ [['p'], ['ə', 'ŋ']]
# ㄅㄥˋ [['p'], ['ə', 'ŋ']]
# ㄅㄧ [['p'], ['i']]
# ㄅㄧ [['p'], ['i']]
# ㄅㄧ [['p'], ['i']]
# ㄅㄧ [['p'], ['i']]
# ㄅㄧˊ [['p'], ['i']]
# ㄅㄧˊ [['p'], ['i']]
# ㄅㄧˇ [['p'], ['i']]
# ㄅㄧˇ [['p'], ['i']]
# ㄅㄧˇ [['p'], ['i']]
# ㄅㄧˇ [['p'], ['i']]
# ㄅㄧˇ [['p'], ['i']]
# ㄅㄧˇ [['p'], ['i']]
# ㄅㄧˇ [['p'], ['i']]
# ㄅㄧˇ [['p'], ['i']]
# ㄅㄧˇ [['p'], ['i']]
# ㄅㄧˇ [['p'], ['i']]
# ㄅㄧˇ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧˋ [['p'], ['i']]
# ㄅㄧㄝ [['p'], ['j'], ['ɛ']]
# ㄅㄧㄝ [['p'], ['j'], ['ɛ']]
# ㄅㄧㄝ [['p'], ['j'], ['ɛ']]
# ㄅㄧㄝˊ [['p'], ['j'], ['ɛ']]
# ㄅㄧㄝˊ [['p'], ['j'], ['ɛ']]
# ㄅㄧㄝˊ [['p'], ['j'], ['ɛ']]
# ㄅㄧㄝˊ [['p'], ['j'], ['ɛ']]
# ㄅㄧㄝˊ [['p'], ['j'], ['ɛ']]
# ㄅㄧㄝˊ [['p'], ['j'], ['ɛ']]
# ㄅㄧㄝˇ [['p'], ['j'], ['ɛ']]
# ㄅㄧㄝˋ [['p'], ['j'], ['ɛ']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠˇ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠˇ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠˇ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠˇ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠˇ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠˇ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠˋ [['p'], ['j'], ['a', 'w']]
# ㄅㄧㄠˋ [['p'], ['j'], ['a', 'w']]
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˇ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˇ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˇ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˇ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˇ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˇ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˇ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˇ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˇ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˇ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['j', 'ɛ', 'n']
# ㄅㄧㄢˋ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣ None
# ['p'] ['I', 'n']
# ㄅㄧㄣˋ None
# ['p'] ['I', 'n']
# ㄅㄧㄣˋ None
# ['p'] ['I', 'n']
# ㄅㄧㄣˋ None
# ['p'] ['I', 'n']
# ㄅㄧㄣˋ None
# ['p'] ['I', 'n']
# ㄅㄧㄣˋ None
# ['p'] ['I', 'n']
# ㄅㄧㄣˋ None
# ['p'] ['I', 'n']
# ㄅㄧㄣˋ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˋ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˋ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˋ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˋ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˋ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˋ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˋ None
# ['p'] ['i', 'ŋ']
# ㄅㄧㄥˋ None
# ㄅㄨ [['p'], ['u']]
# ㄅㄨ [['p'], ['u']]
# ㄅㄨ [['p'], ['u']]
# ㄅㄨˊ [['p'], ['u']]
# ㄅㄨˊ [['p'], ['u']]
# ㄅㄨˇ [['p'], ['u']]
# ㄅㄨˇ [['p'], ['u']]
# ㄅㄨˇ [['p'], ['u']]
# ㄅㄨˇ [['p'], ['u']]
# ㄅㄨˇ [['p'], ['u']]
# ㄅㄨˇ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄅㄨˋ [['p'], ['u']]
# ㄆㄚ [['pʰ'], ['a']]
# ㄆㄚ [['pʰ'], ['a']]
# ㄆㄚ [['pʰ'], ['a']]
# ㄆㄚ [['pʰ'], ['a']]
# ㄆㄚˊ [['pʰ'], ['a']]
# ㄆㄚˊ [['pʰ'], ['a']]
# ㄆㄚˊ [['pʰ'], ['a']]
# ㄆㄚˊ [['pʰ'], ['a']]
# ㄆㄚˊ [['pʰ'], ['a']]
# ㄆㄚˊ [['pʰ'], ['a']]
# ㄆㄚˋ [['pʰ'], ['a']]
# ㄆㄚˋ [['pʰ'], ['a']]
# ㄆㄚˋ [['pʰ'], ['a']]
# ㄆㄚˋ [['pʰ'], ['a']]
# ㄆㄚˋ [['pʰ'], ['a']]
# ˙ㄆㄚ [['pʰ'], ['a']]
# ˙ㄆㄚ [['pʰ'], ['a']]
# ㄆㄛ [['pʰ'], ['ɔ']]
# ㄆㄛ [['pʰ'], ['ɔ']]
# ㄆㄛ [['pʰ'], ['ɔ']]
# ㄆㄛ [['pʰ'], ['ɔ']]
# ㄆㄛ [['pʰ'], ['ɔ']]
# ㄆㄛ [['pʰ'], ['ɔ']]
# ㄆㄛˊ [['pʰ'], ['ɔ']]
# ㄆㄛˊ [['pʰ'], ['ɔ']]
# ㄆㄛˊ [['pʰ'], ['ɔ']]
# ㄆㄛˊ [['pʰ'], ['ɔ']]
# ㄆㄛˊ [['pʰ'], ['ɔ']]
# ㄆㄛˊ [['pʰ'], ['ɔ']]
# ㄆㄛˊ [['pʰ'], ['ɔ']]
# ㄆㄛˇ [['pʰ'], ['ɔ']]
# ㄆㄛˇ [['pʰ'], ['ɔ']]
# ㄆㄛˇ [['pʰ'], ['ɔ']]
# ㄆㄛˇ [['pʰ'], ['ɔ']]
# ㄆㄛˇ [['pʰ'], ['ɔ']]
# ㄆㄛˇ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄛˋ [['pʰ'], ['ɔ']]
# ㄆㄞ [['pʰ'], ['a', 'j']]
# ㄆㄞˊ [['pʰ'], ['a', 'j']]
# ㄆㄞˊ [['pʰ'], ['a', 'j']]
# ㄆㄞˊ [['pʰ'], ['a', 'j']]
# ㄆㄞˊ [['pʰ'], ['a', 'j']]
# ㄆㄞˊ [['pʰ'], ['a', 'j']]
# ㄆㄞˊ [['pʰ'], ['a', 'j']]
# ㄆㄞˇ [['pʰ'], ['a', 'j']]
# ㄆㄞˋ [['pʰ'], ['a', 'j']]
# ㄆㄞˋ [['pʰ'], ['a', 'j']]
# ㄆㄟ [['pʰ'], ['e', 'j']]
# ㄆㄟ [['pʰ'], ['e', 'j']]
# ㄆㄟ [['pʰ'], ['e', 'j']]
# ㄆㄟ [['pʰ'], ['e', 'j']]
# ㄆㄟ [['pʰ'], ['e', 'j']]
# ㄆㄟ [['pʰ'], ['e', 'j']]
# ㄆㄟˊ [['pʰ'], ['e', 'j']]
# ㄆㄟˊ [['pʰ'], ['e', 'j']]
# ㄆㄟˊ [['pʰ'], ['e', 'j']]
# ㄆㄟˊ [['pʰ'], ['e', 'j']]
# ㄆㄟˊ [['pʰ'], ['e', 'j']]
# ㄆㄟˊ [['pʰ'], ['e', 'j']]
# ㄆㄟˊ [['pʰ'], ['e', 'j']]
# ㄆㄟˊ [['pʰ'], ['e', 'j']]
# ㄆㄟˋ [['pʰ'], ['e', 'j']]
# ㄆㄟˋ [['pʰ'], ['e', 'j']]
# ㄆㄟˋ [['pʰ'], ['e', 'j']]
# ㄆㄟˋ [['pʰ'], ['e', 'j']]
# ㄆㄟˋ [['pʰ'], ['e', 'j']]
# ㄆㄟˋ [['pʰ'], ['e', 'j']]
# ㄆㄟˋ [['pʰ'], ['e', 'j']]
# ㄆㄟˋ [['pʰ'], ['e', 'j']]
# ㄆㄟˋ [['pʰ'], ['e', 'j']]
# ㄆㄟˋ [['pʰ'], ['e', 'j']]
# ㄆㄟˋ [['pʰ'], ['e', 'j']]
# ㄆㄟˋ [['pʰ'], ['e', 'j']]
# ㄆㄠ [['pʰ'], ['a', 'w']]
# ㄆㄠ [['pʰ'], ['a', 'w']]
# ㄆㄠ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˊ [['pʰ'], ['a', 'w']]
# ㄆㄠˇ [['pʰ'], ['a', 'w']]
# ㄆㄠˋ [['pʰ'], ['a', 'w']]
# ㄆㄠˋ [['pʰ'], ['a', 'w']]
# ㄆㄠˋ [['pʰ'], ['a', 'w']]
# ㄆㄠˋ [['pʰ'], ['a', 'w']]
# ㄆㄠˋ [['pʰ'], ['a', 'w']]
# ㄆㄠˋ [['pʰ'], ['a', 'w']]
# ㄆㄡ [['pʰ'], ['o', 'w']]
# ㄆㄡˊ [['pʰ'], ['o', 'w']]
# ㄆㄡˊ [['pʰ'], ['o', 'w']]
# ㄆㄡˊ [['pʰ'], ['o', 'w']]
# ㄆㄡˊ [['pʰ'], ['o', 'w']]
# ㄆㄡˇ [['pʰ'], ['o', 'w']]
# ㄆㄡˇ [['pʰ'], ['o', 'w']]
# ㄆㄡˇ [['pʰ'], ['o', 'w']]
# ㄆㄡˇ [['pʰ'], ['o', 'w']]
# ㄆㄡˇ [['pʰ'], ['o', 'w']]
# ㄆㄢ [['pʰ'], ['a', 'n']]
# ㄆㄢ [['pʰ'], ['a', 'n']]
# ㄆㄢ [['pʰ'], ['a', 'n']]
# ㄆㄢ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˊ [['pʰ'], ['a', 'n']]
# ㄆㄢˋ [['pʰ'], ['a', 'n']]
# ㄆㄢˋ [['pʰ'], ['a', 'n']]
# ㄆㄢˋ [['pʰ'], ['a', 'n']]
# ㄆㄢˋ [['pʰ'], ['a', 'n']]
# ㄆㄢˋ [['pʰ'], ['a', 'n']]
# ㄆㄢˋ [['pʰ'], ['a', 'n']]
# ㄆㄢˋ [['pʰ'], ['a', 'n']]
# ㄆㄢˋ [['pʰ'], ['a', 'n']]
# ㄆㄢˋ [['pʰ'], ['a', 'n']]
# ㄆㄢˋ [['pʰ'], ['a', 'n']]
# ㄆㄢˋ [['pʰ'], ['a', 'n']]
# ㄆㄢˋ [['pʰ'], ['a', 'n']]
# ㄆㄣ [['pʰ'], ['ə', 'n']]
# ㄆㄣ [['pʰ'], ['ə', 'n']]
# ㄆㄣ [['pʰ'], ['ə', 'n']]
# ㄆㄣˊ [['pʰ'], ['ə', 'n']]
# ㄆㄣˊ [['pʰ'], ['ə', 'n']]
# ㄆㄣˋ [['pʰ'], ['ə', 'n']]
# ㄆㄣˋ [['pʰ'], ['ə', 'n']]
# ㄆㄤ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˊ [['pʰ'], ['a', 'ŋ']]
# ㄆㄤˋ [['pʰ'], ['a', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˊ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˇ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˋ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˋ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄥˋ [['pʰ'], ['ə', 'ŋ']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˊ [['pʰ'], ['i']]
# ㄆㄧˇ [['pʰ'], ['i']]
# ㄆㄧˇ [['pʰ'], ['i']]
# ㄆㄧˇ [['pʰ'], ['i']]
# ㄆㄧˇ [['pʰ'], ['i']]
# ㄆㄧˇ [['pʰ'], ['i']]
# ㄆㄧˇ [['pʰ'], ['i']]
# ㄆㄧˇ [['pʰ'], ['i']]
# ㄆㄧˇ [['pʰ'], ['i']]
# ㄆㄧˇ [['pʰ'], ['i']]
# ㄆㄧˇ [['pʰ'], ['i']]
# ㄆㄧˇ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧˋ [['pʰ'], ['i']]
# ㄆㄧㄚ [['pʰ'], ['j'], ['a']]
# ㄆㄧㄝ [['pʰ'], ['j'], ['ɛ']]
# ㄆㄧㄝ [['pʰ'], ['j'], ['ɛ']]
# ㄆㄧㄝ [['pʰ'], ['j'], ['ɛ']]
# ㄆㄧㄝ [['pʰ'], ['j'], ['ɛ']]
# ㄆㄧㄝ [['pʰ'], ['j'], ['ɛ']]
# ㄆㄧㄝˇ [['pʰ'], ['j'], ['ɛ']]
# ㄆㄧㄝˇ [['pʰ'], ['j'], ['ɛ']]
# ㄆㄧㄝˋ [['pʰ'], ['j'], ['ɛ']]
# ㄆㄧㄠ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˊ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˊ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˊ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˇ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˇ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˇ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˇ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˇ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˇ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˇ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˇ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˇ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˇ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˇ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˋ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˋ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˋ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˋ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˋ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˋ [['pʰ'], ['j'], ['a', 'w']]
# ㄆㄧㄠˋ [['pʰ'], ['j'], ['a', 'w']]
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˊ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˊ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˊ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˊ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˊ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˊ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˊ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˊ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˊ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˊ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˊ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˊ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˇ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˋ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˋ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˋ None
# ['pʰ'] ['j', 'ɛ', 'n']
# ㄆㄧㄢˋ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˊ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˊ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˊ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˊ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˊ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˊ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˊ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˊ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˊ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˊ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˇ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˋ None
# ['pʰ'] ['I', 'n']
# ㄆㄧㄣˋ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˋ None
# ㄆㄨ [['pʰ'], ['u']]
# ㄆㄨ [['pʰ'], ['u']]
# ㄆㄨ [['pʰ'], ['u']]
# ㄆㄨ [['pʰ'], ['u']]
# ㄆㄨ [['pʰ'], ['u']]
# ㄆㄨ [['pʰ'], ['u']]
# ㄆㄨ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˊ [['pʰ'], ['u']]
# ㄆㄨˇ [['pʰ'], ['u']]
# ㄆㄨˇ [['pʰ'], ['u']]
# ㄆㄨˇ [['pʰ'], ['u']]
# ㄆㄨˇ [['pʰ'], ['u']]
# ㄆㄨˇ [['pʰ'], ['u']]
# ㄆㄨˇ [['pʰ'], ['u']]
# ㄆㄨˇ [['pʰ'], ['u']]
# ㄆㄨˇ [['pʰ'], ['u']]
# ㄆㄨˋ [['pʰ'], ['u']]
# ㄆㄨˋ [['pʰ'], ['u']]
# ㄆㄨˋ [['pʰ'], ['u']]
# ㄆㄨˋ [['pʰ'], ['u']]
# ㄆㄨˋ [['pʰ'], ['u']]
# ㄇㄚ [['m'], ['a']]
# ㄇㄚ [['m'], ['a']]
# ㄇㄚ [['m'], ['a']]
# ㄇㄚ [['m'], ['a']]
# ㄇㄚˊ [['m'], ['a']]
# ㄇㄚˊ [['m'], ['a']]
# ㄇㄚˊ [['m'], ['a']]
# ㄇㄚˊ [['m'], ['a']]
# ㄇㄚˊ [['m'], ['a']]
# ㄇㄚˊ [['m'], ['a']]
# ㄇㄚˇ [['m'], ['a']]
# ㄇㄚˇ [['m'], ['a']]
# ㄇㄚˇ [['m'], ['a']]
# ㄇㄚˇ [['m'], ['a']]
# ㄇㄚˇ [['m'], ['a']]
# ㄇㄚˇ [['m'], ['a']]
# ㄇㄚˇ [['m'], ['a']]
# ㄇㄚˋ [['m'], ['a']]
# ㄇㄚˋ [['m'], ['a']]
# ㄇㄚˋ [['m'], ['a']]
# ㄇㄚˋ [['m'], ['a']]
# ˙ㄇㄚ [['m'], ['a']]
# ˙ㄇㄚ [['m'], ['a']]
# ˙ㄇㄚ [['m'], ['a']]
# ˙ㄇㄚ [['m'], ['a']]
# ㄇㄛ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˊ [['m'], ['ɔ']]
# ㄇㄛˇ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ㄇㄛˋ [['m'], ['ɔ']]
# ˙ㄇㄜ [['m'], ['ɤ']]
# ˙ㄇㄜ [['m'], ['ɤ']]
# ㄇㄞˊ [['m'], ['a', 'j']]
# ㄇㄞˊ [['m'], ['a', 'j']]
# ㄇㄞˊ [['m'], ['a', 'j']]
# ㄇㄞˇ [['m'], ['a', 'j']]
# ㄇㄞˋ [['m'], ['a', 'j']]
# ㄇㄞˋ [['m'], ['a', 'j']]
# ㄇㄞˋ [['m'], ['a', 'j']]
# ㄇㄞˋ [['m'], ['a', 'j']]
# ㄇㄞˋ [['m'], ['a', 'j']]
# ㄇㄞˋ [['m'], ['a', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˊ [['m'], ['e', 'j']]
# ㄇㄟˇ [['m'], ['e', 'j']]
# ㄇㄟˇ [['m'], ['e', 'j']]
# ㄇㄟˇ [['m'], ['e', 'j']]
# ㄇㄟˇ [['m'], ['e', 'j']]
# ㄇㄟˇ [['m'], ['e', 'j']]
# ㄇㄟˇ [['m'], ['e', 'j']]
# ㄇㄟˇ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄟˋ [['m'], ['e', 'j']]
# ㄇㄠ [['m'], ['a', 'w']]
# ㄇㄠ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˊ [['m'], ['a', 'w']]
# ㄇㄠˇ [['m'], ['a', 'w']]
# ㄇㄠˇ [['m'], ['a', 'w']]
# ㄇㄠˇ [['m'], ['a', 'w']]
# ㄇㄠˇ [['m'], ['a', 'w']]
# ㄇㄠˇ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄠˋ [['m'], ['a', 'w']]
# ㄇㄡˊ [['m'], ['o', 'w']]
# ㄇㄡˊ [['m'], ['o', 'w']]
# ㄇㄡˊ [['m'], ['o', 'w']]
# ㄇㄡˊ [['m'], ['o', 'w']]
# ㄇㄡˊ [['m'], ['o', 'w']]
# ㄇㄡˊ [['m'], ['o', 'w']]
# ㄇㄡˊ [['m'], ['o', 'w']]
# ㄇㄡˊ [['m'], ['o', 'w']]
# ㄇㄡˊ [['m'], ['o', 'w']]
# ㄇㄡˊ [['m'], ['o', 'w']]
# ㄇㄡˊ [['m'], ['o', 'w']]
# ㄇㄡˇ [['m'], ['o', 'w']]
# ㄇㄡˇ [['m'], ['o', 'w']]
# ㄇㄡˇ [['m'], ['o', 'w']]
# ㄇㄡˋ [['m'], ['o', 'w']]
# ㄇㄡˋ [['m'], ['o', 'w']]
# ㄇㄡˋ [['m'], ['o', 'w']]
# ㄇㄡˋ [['m'], ['o', 'w']]
# ㄇㄡˋ [['m'], ['o', 'w']]
# ㄇㄡˋ [['m'], ['o', 'w']]
# ㄇㄢ [['m'], ['a', 'n']]
# ㄇㄢ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˊ [['m'], ['a', 'n']]
# ㄇㄢˇ [['m'], ['a', 'n']]
# ㄇㄢˇ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄢˋ [['m'], ['a', 'n']]
# ㄇㄣ [['m'], ['ə', 'n']]
# ㄇㄣ [['m'], ['ə', 'n']]
# ㄇㄣˊ [['m'], ['ə', 'n']]
# ㄇㄣˊ [['m'], ['ə', 'n']]
# ㄇㄣˊ [['m'], ['ə', 'n']]
# ㄇㄣˊ [['m'], ['ə', 'n']]
# ㄇㄣˊ [['m'], ['ə', 'n']]
# ㄇㄣˊ [['m'], ['ə', 'n']]
# ㄇㄣˊ [['m'], ['ə', 'n']]
# ㄇㄣˇ [['m'], ['ə', 'n']]
# ㄇㄣˋ [['m'], ['ə', 'n']]
# ㄇㄣˋ [['m'], ['ə', 'n']]
# ㄇㄣˋ [['m'], ['ə', 'n']]
# ㄇㄣˋ [['m'], ['ə', 'n']]
# ˙ㄇㄣ [['m'], ['ə', 'n']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˊ [['m'], ['a', 'ŋ']]
# ㄇㄤˇ [['m'], ['a', 'ŋ']]
# ㄇㄤˇ [['m'], ['a', 'ŋ']]
# ㄇㄤˇ [['m'], ['a', 'ŋ']]
# ㄇㄤˇ [['m'], ['a', 'ŋ']]
# ㄇㄤˇ [['m'], ['a', 'ŋ']]
# ㄇㄥ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˊ [['m'], ['ə', 'ŋ']]
# ㄇㄥˇ [['m'], ['ə', 'ŋ']]
# ㄇㄥˇ [['m'], ['ə', 'ŋ']]
# ㄇㄥˇ [['m'], ['ə', 'ŋ']]
# ㄇㄥˇ [['m'], ['ə', 'ŋ']]
# ㄇㄥˇ [['m'], ['ə', 'ŋ']]
# ㄇㄥˇ [['m'], ['ə', 'ŋ']]
# ㄇㄥˇ [['m'], ['ə', 'ŋ']]
# ㄇㄥˇ [['m'], ['ə', 'ŋ']]
# ㄇㄥˇ [['m'], ['ə', 'ŋ']]
# ㄇㄥˇ [['m'], ['ə', 'ŋ']]
# ㄇㄥˇ [['m'], ['ə', 'ŋ']]
# ㄇㄥˇ [['m'], ['ə', 'ŋ']]
# ㄇㄥˋ [['m'], ['ə', 'ŋ']]
# ㄇㄥˋ [['m'], ['ə', 'ŋ']]
# ㄇㄥˋ [['m'], ['ə', 'ŋ']]
# ㄇㄧ [['m'], ['i']]
# ㄇㄧ [['m'], ['i']]
# ㄇㄧ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˊ [['m'], ['i']]
# ㄇㄧˇ [['m'], ['i']]
# ㄇㄧˇ [['m'], ['i']]
# ㄇㄧˇ [['m'], ['i']]
# ㄇㄧˇ [['m'], ['i']]
# ㄇㄧˇ [['m'], ['i']]
# ㄇㄧˇ [['m'], ['i']]
# ㄇㄧˇ [['m'], ['i']]
# ㄇㄧˇ [['m'], ['i']]
# ㄇㄧˇ [['m'], ['i']]
# ㄇㄧˇ [['m'], ['i']]
# ㄇㄧˇ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧˋ [['m'], ['i']]
# ㄇㄧㄝ [['m'], ['j'], ['ɛ']]
# ㄇㄧㄝ [['m'], ['j'], ['ɛ']]
# ㄇㄧㄝ [['m'], ['j'], ['ɛ']]
# ㄇㄧㄝˋ [['m'], ['j'], ['ɛ']]
# ㄇㄧㄝˋ [['m'], ['j'], ['ɛ']]
# ㄇㄧㄝˋ [['m'], ['j'], ['ɛ']]
# ㄇㄧㄝˋ [['m'], ['j'], ['ɛ']]
# ㄇㄧㄝˋ [['m'], ['j'], ['ɛ']]
# ㄇㄧㄝˋ [['m'], ['j'], ['ɛ']]
# ㄇㄧㄝˋ [['m'], ['j'], ['ɛ']]
# ㄇㄧㄠ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˊ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˊ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˊ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˇ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˇ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˇ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˇ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˇ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˇ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˇ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˇ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˋ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˋ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄠˋ [['m'], ['j'], ['a', 'w']]
# ㄇㄧㄡˋ [['m'], ['j'], ['o', 'w']]
# ㄇㄧㄡˋ [['m'], ['j'], ['o', 'w']]
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˊ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˊ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˊ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˊ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˊ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˊ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˊ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˊ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˊ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˇ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˋ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˋ None
# ['m'] ['j', 'ɛ', 'n']
# ㄇㄧㄢˋ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˊ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˊ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˊ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˊ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˊ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˊ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˊ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˊ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˊ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˊ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˊ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['I', 'n']
# ㄇㄧㄣˇ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˊ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˇ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˇ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˇ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˇ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˇ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˋ None
# ['m'] ['i', 'ŋ']
# ㄇㄧㄥˋ None
# ㄇㄨˊ [['m'], ['u']]
# ㄇㄨˊ [['m'], ['u']]
# ㄇㄨˊ [['m'], ['u']]
# ㄇㄨˇ [['m'], ['u']]
# ㄇㄨˇ [['m'], ['u']]
# ㄇㄨˇ [['m'], ['u']]
# ㄇㄨˇ [['m'], ['u']]
# ㄇㄨˇ [['m'], ['u']]
# ㄇㄨˇ [['m'], ['u']]
# ㄇㄨˇ [['m'], ['u']]
# ㄇㄨˇ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄇㄨˋ [['m'], ['u']]
# ㄈㄚ [['f'], ['a']]
# ㄈㄚ [['f'], ['a']]
# ㄈㄚ [['f'], ['a']]
# ㄈㄚ [['f'], ['a']]
# ㄈㄚˊ [['f'], ['a']]
# ㄈㄚˊ [['f'], ['a']]
# ㄈㄚˊ [['f'], ['a']]
# ㄈㄚˊ [['f'], ['a']]
# ㄈㄚˊ [['f'], ['a']]
# ㄈㄚˊ [['f'], ['a']]
# ㄈㄚˊ [['f'], ['a']]
# ㄈㄚˊ [['f'], ['a']]
# ㄈㄚˇ [['f'], ['a']]
# ㄈㄚˇ [['f'], ['a']]
# ㄈㄚˇ [['f'], ['a']]
# ㄈㄚˇ [['f'], ['a']]
# ㄈㄚˋ [['f'], ['a']]
# ㄈㄛˊ [['f'], ['ɔ']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟ [['f'], ['e', 'j']]
# ㄈㄟˊ [['f'], ['e', 'j']]
# ㄈㄟˊ [['f'], ['e', 'j']]
# ㄈㄟˊ [['f'], ['e', 'j']]
# ㄈㄟˊ [['f'], ['e', 'j']]
# ㄈㄟˇ [['f'], ['e', 'j']]
# ㄈㄟˇ [['f'], ['e', 'j']]
# ㄈㄟˇ [['f'], ['e', 'j']]
# ㄈㄟˇ [['f'], ['e', 'j']]
# ㄈㄟˇ [['f'], ['e', 'j']]
# ㄈㄟˇ [['f'], ['e', 'j']]
# ㄈㄟˇ [['f'], ['e', 'j']]
# ㄈㄟˇ [['f'], ['e', 'j']]
# ㄈㄟˇ [['f'], ['e', 'j']]
# ㄈㄟˇ [['f'], ['e', 'j']]
# ㄈㄟˇ [['f'], ['e', 'j']]
# ㄈㄟˇ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄟˋ [['f'], ['e', 'j']]
# ㄈㄡ [['f'], ['o', 'w']]
# ㄈㄡ [['f'], ['o', 'w']]
# ㄈㄡˊ [['f'], ['o', 'w']]
# ㄈㄡˊ [['f'], ['o', 'w']]
# ㄈㄡˊ [['f'], ['o', 'w']]
# ㄈㄡˊ [['f'], ['o', 'w']]
# ㄈㄡˇ [['f'], ['o', 'w']]
# ㄈㄡˇ [['f'], ['o', 'w']]
# ㄈㄡˇ [['f'], ['o', 'w']]
# ㄈㄡˇ [['f'], ['o', 'w']]
# ㄈㄡˋ [['f'], ['o', 'w']]
# ㄈㄡˋ [['f'], ['o', 'w']]
# ㄈㄢ [['f'], ['a', 'n']]
# ㄈㄢ [['f'], ['a', 'n']]
# ㄈㄢ [['f'], ['a', 'n']]
# ㄈㄢ [['f'], ['a', 'n']]
# ㄈㄢ [['f'], ['a', 'n']]
# ㄈㄢ [['f'], ['a', 'n']]
# ㄈㄢ [['f'], ['a', 'n']]
# ㄈㄢ [['f'], ['a', 'n']]
# ㄈㄢ [['f'], ['a', 'n']]
# ㄈㄢ [['f'], ['a', 'n']]
# ㄈㄢ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˊ [['f'], ['a', 'n']]
# ㄈㄢˇ [['f'], ['a', 'n']]
# ㄈㄢˇ [['f'], ['a', 'n']]
# ㄈㄢˋ [['f'], ['a', 'n']]
# ㄈㄢˋ [['f'], ['a', 'n']]
# ㄈㄢˋ [['f'], ['a', 'n']]
# ㄈㄢˋ [['f'], ['a', 'n']]
# ㄈㄢˋ [['f'], ['a', 'n']]
# ㄈㄢˋ [['f'], ['a', 'n']]
# ㄈㄢˋ [['f'], ['a', 'n']]
# ㄈㄢˋ [['f'], ['a', 'n']]
# ㄈㄢˋ [['f'], ['a', 'n']]
# ㄈㄢˋ [['f'], ['a', 'n']]
# ㄈㄢˋ [['f'], ['a', 'n']]
# ㄈㄢˋ [['f'], ['a', 'n']]
# ㄈㄣ [['f'], ['ə', 'n']]
# ㄈㄣ [['f'], ['ə', 'n']]
# ㄈㄣ [['f'], ['ə', 'n']]
# ㄈㄣ [['f'], ['ə', 'n']]
# ㄈㄣ [['f'], ['ə', 'n']]
# ㄈㄣ [['f'], ['ə', 'n']]
# ㄈㄣ [['f'], ['ə', 'n']]
# ㄈㄣ [['f'], ['ə', 'n']]
# ㄈㄣ [['f'], ['ə', 'n']]
# ㄈㄣ [['f'], ['ə', 'n']]
# ㄈㄣ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˊ [['f'], ['ə', 'n']]
# ㄈㄣˇ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄣˋ [['f'], ['ə', 'n']]
# ㄈㄤ [['f'], ['a', 'ŋ']]
# ㄈㄤ [['f'], ['a', 'ŋ']]
# ㄈㄤ [['f'], ['a', 'ŋ']]
# ㄈㄤ [['f'], ['a', 'ŋ']]
# ㄈㄤ [['f'], ['a', 'ŋ']]
# ㄈㄤ [['f'], ['a', 'ŋ']]
# ㄈㄤ [['f'], ['a', 'ŋ']]
# ㄈㄤ [['f'], ['a', 'ŋ']]
# ㄈㄤ [['f'], ['a', 'ŋ']]
# ㄈㄤˊ [['f'], ['a', 'ŋ']]
# ㄈㄤˊ [['f'], ['a', 'ŋ']]
# ㄈㄤˊ [['f'], ['a', 'ŋ']]
# ㄈㄤˊ [['f'], ['a', 'ŋ']]
# ㄈㄤˊ [['f'], ['a', 'ŋ']]
# ㄈㄤˊ [['f'], ['a', 'ŋ']]
# ㄈㄤˇ [['f'], ['a', 'ŋ']]
# ㄈㄤˇ [['f'], ['a', 'ŋ']]
# ㄈㄤˇ [['f'], ['a', 'ŋ']]
# ㄈㄤˇ [['f'], ['a', 'ŋ']]
# ㄈㄤˇ [['f'], ['a', 'ŋ']]
# ㄈㄤˇ [['f'], ['a', 'ŋ']]
# ㄈㄤˇ [['f'], ['a', 'ŋ']]
# ㄈㄤˇ [['f'], ['a', 'ŋ']]
# ㄈㄤˇ [['f'], ['a', 'ŋ']]
# ㄈㄤˇ [['f'], ['a', 'ŋ']]
# ㄈㄤˋ [['f'], ['a', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥ [['f'], ['ə', 'ŋ']]
# ㄈㄥˊ [['f'], ['ə', 'ŋ']]
# ㄈㄥˊ [['f'], ['ə', 'ŋ']]
# ㄈㄥˊ [['f'], ['ə', 'ŋ']]
# ㄈㄥˊ [['f'], ['ə', 'ŋ']]
# ㄈㄥˊ [['f'], ['ə', 'ŋ']]
# ㄈㄥˇ [['f'], ['ə', 'ŋ']]
# ㄈㄥˇ [['f'], ['ə', 'ŋ']]
# ㄈㄥˇ [['f'], ['ə', 'ŋ']]
# ㄈㄥˋ [['f'], ['ə', 'ŋ']]
# ㄈㄥˋ [['f'], ['ə', 'ŋ']]
# ㄈㄥˋ [['f'], ['ə', 'ŋ']]
# ㄈㄥˋ [['f'], ['ə', 'ŋ']]
# ㄈㄥˋ [['f'], ['ə', 'ŋ']]
# ㄈㄥˋ [['f'], ['ə', 'ŋ']]
# ㄈㄥˋ [['f'], ['ə', 'ŋ']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˊ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˇ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄈㄨˋ [['f'], ['u']]
# ㄉㄚ [['t'], ['a']]
# ㄉㄚ [['t'], ['a']]
# ㄉㄚ [['t'], ['a']]
# ㄉㄚ [['t'], ['a']]
# ㄉㄚ [['t'], ['a']]
# ㄉㄚ [['t'], ['a']]
# ㄉㄚ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˊ [['t'], ['a']]
# ㄉㄚˇ [['t'], ['a']]
# ㄉㄚˋ [['t'], ['a']]
# ˙ㄉㄚ [['t'], ['a']]
# ˙ㄉㄚ [['t'], ['a']]
# ㄉㄜ [['t'], ['ɤ']]
# ㄉㄜˊ [['t'], ['ɤ']]
# ㄉㄜˊ [['t'], ['ɤ']]
# ˙ㄉㄜ [['t'], ['ɤ']]
# ˙ㄉㄜ [['t'], ['ɤ']]
# ˙ㄉㄜ [['t'], ['ɤ']]
# ˙ㄉㄜ [['t'], ['ɤ']]
# ㄉㄞ [['t'], ['a', 'j']]
# ㄉㄞ [['t'], ['a', 'j']]
# ㄉㄞ [['t'], ['a', 'j']]
# ㄉㄞˇ [['t'], ['a', 'j']]
# ㄉㄞˇ [['t'], ['a', 'j']]
# ㄉㄞˇ [['t'], ['a', 'j']]
# ㄉㄞˇ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄞˋ [['t'], ['a', 'j']]
# ㄉㄟˇ [['t'], ['e', 'j']]
# ㄉㄠ [['t'], ['a', 'w']]
# ㄉㄠ [['t'], ['a', 'w']]
# ㄉㄠ [['t'], ['a', 'w']]
# ㄉㄠ [['t'], ['a', 'w']]
# ㄉㄠ [['t'], ['a', 'w']]
# ㄉㄠˊ [['t'], ['a', 'w']]
# ㄉㄠˇ [['t'], ['a', 'w']]
# ㄉㄠˇ [['t'], ['a', 'w']]
# ㄉㄠˇ [['t'], ['a', 'w']]
# ㄉㄠˇ [['t'], ['a', 'w']]
# ㄉㄠˇ [['t'], ['a', 'w']]
# ㄉㄠˇ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄠˋ [['t'], ['a', 'w']]
# ㄉㄡ [['t'], ['o', 'w']]
# ㄉㄡ [['t'], ['o', 'w']]
# ㄉㄡ [['t'], ['o', 'w']]
# ㄉㄡ [['t'], ['o', 'w']]
# ㄉㄡˇ [['t'], ['o', 'w']]
# ㄉㄡˇ [['t'], ['o', 'w']]
# ㄉㄡˇ [['t'], ['o', 'w']]
# ㄉㄡˇ [['t'], ['o', 'w']]
# ㄉㄡˋ [['t'], ['o', 'w']]
# ㄉㄡˋ [['t'], ['o', 'w']]
# ㄉㄡˋ [['t'], ['o', 'w']]
# ㄉㄡˋ [['t'], ['o', 'w']]
# ㄉㄡˋ [['t'], ['o', 'w']]
# ㄉㄡˋ [['t'], ['o', 'w']]
# ㄉㄡˋ [['t'], ['o', 'w']]
# ㄉㄡˋ [['t'], ['o', 'w']]
# ㄉㄡˋ [['t'], ['o', 'w']]
# ㄉㄢ [['t'], ['a', 'n']]
# ㄉㄢ [['t'], ['a', 'n']]
# ㄉㄢ [['t'], ['a', 'n']]
# ㄉㄢ [['t'], ['a', 'n']]
# ㄉㄢ [['t'], ['a', 'n']]
# ㄉㄢ [['t'], ['a', 'n']]
# ㄉㄢ [['t'], ['a', 'n']]
# ㄉㄢ [['t'], ['a', 'n']]
# ㄉㄢ [['t'], ['a', 'n']]
# ㄉㄢ [['t'], ['a', 'n']]
# ...
# ㄅㄠˇ [['p'], ['a', 'w']] ㄋㄨㄢˇ [['n'], ['w'], ['a', 'n']] ㄕㄥ [['ʂ'], ['ə', 'ŋ']] ㄧㄣˊ ['I', 'n'] ㄩˋ [['y']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄋㄨㄢˇ [['n'], ['w'], ['a', 'n']] ㄙ [['s'], ['ɨ']] ㄧㄣˊ ['I', 'n'] ㄩˋ [['y']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄌㄢˇ [['l'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄍㄜˊ ㄦ [['k'], ['ɤ'], [], ['ɚ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄎㄢˋ [['kʰ'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ㄉㄞˋ [['t'], ['a', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ㄉㄢ [['t'], ['a', 'n']] ㄨㄟˋ [['w'], ['e', 'j']] ['tʂ'] ['o', 'ŋ']
# ㄓㄨㄥˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ['t'] ['j', 'ɛ', 'n']
# ㄉㄧㄢˇ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ㄉㄨˋ [['t'], ['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ['kʰ'] ['o', 'ŋ']
# ㄎㄨㄥ None ㄑㄧˋ [['tɕʰ'], ['i']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ㄏㄨㄚˋ [['x'], ['w'], ['a']] ㄏㄜˊ [['x'], ['ɤ']] ㄨˋ [['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ['x'] ['o', 'ŋ']
# ㄏㄨㄥ None ㄓㄚˋ [['tʂ'], ['a']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ㄓ [['tʂ'], ['ɨ']] ㄈㄤˊ [['f'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ㄓ [['tʂ'], ['ɨ']] ㄈㄤˊ [['f'], ['a', 'ŋ']] ㄙㄨㄢ [['s'], ['w'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ㄓㄥ [['tʂ'], ['ə', 'ŋ']] ㄑㄧˋ [['tɕʰ'], ['i']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ㄓㄥ [['tʂ'], ['ə', 'ŋ']] ㄑㄧˋ [['tɕʰ'], ['i']] ㄧㄚ [['j'], ['a']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ㄓㄨㄤˋ [['tʂ'], ['w'], ['a', 'ŋ']] ㄊㄞˋ [['tʰ'], ['a', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ㄕ [['ʂ'], ['ɨ']] ㄉㄨˋ [['t'], ['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ㄕㄨㄟˇ [['ʂ'], ['w'], ['e', 'j']] ㄓㄥ [['tʂ'], ['ə', 'ŋ']] ㄑㄧˋ [['tɕʰ'], ['i']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄜˊ [['x'], ['ɤ']] ['ʐ'] ['o', 'ŋ']
# ㄖㄨㄥˊ None ㄧㄝˋ [['j'], ['ɛ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄢˋ [['x'], ['a', 'n']] ㄅㄨˋ [['p'], ['u']] ㄓ [['tʂ'], ['ɨ']] ㄜˋ [['ɤ']] ㄏㄢˋ [['x'], ['a', 'n']] ㄐㄧ [['tɕ'], ['i']]
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕ'] ['i', 'ŋ']
# ㄐㄧㄥ None ㄈㄥ [['f'], ['ə', 'ŋ']] ㄕㄨㄤ [['ʂ'], ['w'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕ'] ['i', 'ŋ']
# ㄐㄧㄥ None ㄕˋ [['ʂ'], ['ɨ']] ㄍㄨˋ [['k'], ['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕ'] ['i', 'ŋ']
# ㄐㄧㄥ None ㄕㄨㄤ [['ʂ'], ['w'], ['a', 'ŋ']] ㄒㄩㄝˇ [['ɕ'], ['ɥ'], ['ɛ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕ'] ['i', 'ŋ']
# ㄐㄧㄥ None ㄧㄡ [['j'], ['o', 'w']] ㄏㄨㄢˋ [['x'], ['w'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄒㄩㄝˊ [['ɕ'], ['ɥ'], ['ɛ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄒㄩㄝˊ [['ɕ'], ['ɥ'], ['ɛ']] ㄒㄧㄡˋ [['ɕ'], ['j'], ['o', 'w']] ㄘㄞˊ [['tsʰ'], ['a', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄒㄩㄝˊ [['ɕ'], ['ɥ'], ['ɛ']] ㄓ [['tʂ'], ['ɨ']] ㄕˋ [['ʂ'], ['ɨ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄓㄨㄤˋ [['tʂ'], ['w'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄔㄤˊ [['tʂʰ'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄕˊ [['ʂ'], ['ɨ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄕˊ [['ʂ'], ['ɨ']] ㄋㄨㄢˇ [['n'], ['w'], ['a', 'n']] ㄧ [['i']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄕˊ [['ʂ'], ['ɨ']] ['tʂ'] ['o', 'ŋ']
# ㄓㄨㄥ None ㄖˋ [['ʐ'], ['ɨ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄕˊ [['ʂ'], ['ɨ']] ['tʂ'] ['o', 'ŋ']
# ㄓㄨㄥ None ㄖˋ [['ʐ'], ['ɨ']] ， [[]] ㄨˊ [['u']] ㄙㄨㄛˇ [['s'], ['w'], ['ɔ']] ㄩㄥˋ ['j', 'o', 'ŋ'] ['ɕ'] ['I', 'n']
# ㄒㄧㄣ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄕㄡˋ [['ʂ'], ['o', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄖㄣˊ [['ʐ'], ['ə', 'n']] ㄅㄨˋ [['p'], ['u']] ㄓ [['tʂ'], ['ɨ']] ㄜˋ [['ɤ']] ㄖㄣˊ [['ʐ'], ['ə', 'n']] ㄐㄧ [['tɕ'], ['i']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄗㄨˊ [['ts'], ['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄘㄢ [['tsʰ'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄘㄢ [['tsʰ'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄧˇ [['i']] ㄌㄠˇ [['l'], ['a', 'w']] ['tɕʰ'] ['ɥ', 'ɛ', 'n']
# ㄑㄩㄢˊ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄧㄤˊ [['j'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄨㄣˊ [['w'], ['ə', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄇㄨˇ [['m'], ['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄋㄧㄠˇ [['n'], ['j'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ˙ㄗ [['ts'], ['ɨ']]
# ㄅㄠˇ ㄦ [['p'], ['a', 'w'], [], ['ɚ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄩˇ [['y']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄅㄟˋ [['p'], ['e', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄅㄠˇ [['p'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None ㄗㄨㄛˋ [['ts'], ['w'], ['ɔ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄇㄚˇ [['m'], ['a']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄇㄚˇ [['m'], ['a']] ㄒㄧㄤ [['ɕ'], ['j'], ['a', 'ŋ']] ㄔㄜ [['tʂʰ'], ['ɤ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄇㄛˊ [['m'], ['ɔ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄈㄚˊ [['f'], ['a']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄈㄤ [['f'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄈㄤ [['f'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄉㄞˋ [['t'], ['a', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄉㄞˋ [['t'], ['a', 'j']] ㄑㄧㄠˊ [['tɕʰ'], ['j'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄉㄠ [['t'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄉㄠ [['t'], ['a', 'w']] ㄅㄨˋ [['p'], ['u']] ㄌㄠˇ [['l'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄉㄠ [['t'], ['a', 'w']] ㄨㄟˋ [['w'], ['e', 'j']] ㄌㄠˇ [['l'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄉㄠˇ [['t'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄉㄧˇ [['t'], ['i']] ['ɕ'] ['j', 'ɛ', 'n']
# ㄒㄧㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄉㄧˋ [['t'], ['i']]
# ㄅㄠˇ [['p'], ['a', 'w']] ['t'] ['j', 'ɛ', 'n']
# ㄉㄧㄢˇ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['t'] ['j', 'ɛ', 'n']
# ㄉㄧㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['t'] ['j', 'ɛ', 'n']
# ㄉㄧㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['t'] ['i', 'ŋ']
# ㄉㄧㄥˇ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['t'] ['i', 'ŋ']
# ㄉㄧㄥˇ None ㄒㄩㄣ [['ɕ'], ['ɥ'], ['ə', 'n']] ㄓㄤ [['tʂ'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄊㄚˇ [['tʰ'], ['a']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄊㄚˇ [['tʰ'], ['a']] ㄊㄤˊ [['tʰ'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄊㄚˇ [['tʰ'], ['a']] ['ɕ'] ['j', 'ɛ', 'n']
# ㄒㄧㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄊㄚˇ [['tʰ'], ['a']] ㄕ [['ʂ'], ['ɨ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄊㄚˇ [['tʰ'], ['a']] ㄕˋ [['ʂ'], ['ɨ']] ㄒㄧㄝˇ [['ɕ'], ['j'], ['ɛ']] ㄗㄨㄛˋ [['ts'], ['w'], ['ɔ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄊㄚˇ [['tʰ'], ['a']] ㄘㄞˋ [['tsʰ'], ['a', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄊㄜˋ [['tʰ'], ['ɤ']] ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄋㄧㄝˋ [['n'], ['j'], ['ɛ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄌㄢˊ [['l'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄌㄢˊ [['l'], ['a', 'n']] ㄙㄜˋ [['s'], ['ɤ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄌㄧˇ [['l'], ['i']] ㄅㄠˇ [['p'], ['a', 'w']] ㄑㄧˋ [['tɕʰ'], ['i']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄌㄧˋ [['l'], ['i']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄌㄧˋ [['l'], ['i']] ㄌㄞˊ [['l'], ['a', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ['l'] ['j', 'ɛ', 'n']
# ㄌㄧㄢˊ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['l'] ['j', 'ɛ', 'n']
# ㄌㄧㄢˊ None ㄉㄥ [['t'], ['ə', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄌㄨˋ [['l'], ['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄌㄨˋ [['l'], ['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄍㄞˋ [['k'], ['a', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄍㄞˋ [['k'], ['a', 'j']] ㄕㄢ [['ʂ'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄍㄨㄟˋ [['k'], ['w'], ['e', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄍㄨㄢ [['k'], ['w'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄍㄨㄤ [['k'], ['w'], ['a', 'ŋ']] ㄐㄧㄚ [['tɕ'], ['j'], ['a']] ㄏㄜˊ [['x'], ['ɤ']] ㄓㄤ [['tʂ'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄎㄨˋ [['kʰ'], ['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄠˋ [['x'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄢˊ [['x'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄨㄛˋ [['x'], ['w'], ['ɔ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄨㄛˋ [['x'], ['w'], ['ɔ']] ㄋㄢˊ [['n'], ['a', 'n']] ㄕㄡˋ [['ʂ'], ['o', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄐㄧ [['tɕ'], ['i']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄐㄧ [['tɕ'], ['i']] ['ɕ'] ['j', 'ɛ', 'n']
# ㄒㄧㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄐㄧㄠˋ [['tɕ'], ['j'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕ'] ['j', 'ɛ', 'n']
# ㄐㄧㄢ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕ'] ['j', 'ɛ', 'n']
# ㄐㄧㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕ'] ['j', 'ɛ', 'n']
# ㄐㄧㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕ'] ['I', 'n']
# ㄐㄧㄣˋ None ㄓㄞ [['tʂ'], ['a', 'j']] ㄈㄚˇ [['f'], ['a']] ㄊㄧㄝˋ [['tʰ'], ['j'], ['ɛ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕ'] ['ɥ', 'ɛ', 'n']
# ㄐㄩㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕ'] ['ɥ', 'ɛ', 'n']
# ㄐㄩㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄑㄧˋ [['tɕʰ'], ['i']]
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕʰ'] ['i', 'ŋ']
# ㄑㄧㄥˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕʰ'] ['ɥ', 'ɛ', 'n']
# ㄑㄩㄢˊ None ㄊㄧˊ [['tʰ'], ['i']] ㄐㄩˇ [['tɕ'], ['y']] ㄙ [['s'], ['ɨ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ['tɕʰ'] ['ɥ', 'ɛ', 'n']
# ㄑㄩㄢˊ None ㄐㄩˊ [['tɕ'], ['y']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄒㄧˊ [['ɕ'], ['i']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄒㄧㄤˋ [['ɕ'], ['j'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄒㄧㄤˋ [['ɕ'], ['j'], ['a', 'ŋ']] ㄓㄨㄤ [['tʂ'], ['w'], ['a', 'ŋ']] ㄧㄢˊ ['j', 'ɛ', 'n']
# ㄅㄠˇ [['p'], ['a', 'w']] ['ɕ'] ['i', 'ŋ']
# ㄒㄧㄥ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['ɕ'] ['i', 'ŋ']
# ㄒㄧㄥ None ['ɕ'] ['j', 'ɛ', 'n']
# ㄒㄧㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ['ɕ'] ['ɥ', 'ɛ', 'n']
# ㄒㄩㄢ None ㄉㄥ [['t'], ['ə', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄓˋ [['tʂ'], ['ɨ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄓㄡ [['tʂ'], ['o', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄓㄤ [['tʂ'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄓㄨ [['tʂ'], ['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄓㄨ [['tʂ'], ['u']] ㄔㄚˊ [['tʂʰ'], ['a']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄓㄨ [['tʂ'], ['u']] ㄕˋ [['ʂ'], ['ɨ']] ['p'] ['i', 'ŋ']
# ㄅㄧㄥˇ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄓㄨㄤ [['tʂ'], ['w'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ['tʂ'] ['o', 'ŋ']
# ㄓㄨㄥˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄔㄚˋ [['tʂʰ'], ['a']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄔㄞ [['tʂʰ'], ['a', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄔㄞ [['tʂʰ'], ['a', 'j']] ㄌㄡˊ [['l'], ['o', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄔㄠ [['tʂʰ'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄔㄤ [['tʂʰ'], ['a', 'ŋ']] ['ɕ'] ['j', 'ɛ', 'n']
# ㄒㄧㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄔㄥˊ [['tʂʰ'], ['ə', 'ŋ']] ㄊㄧㄝˇ [['tʰ'], ['j'], ['ɛ']] ㄌㄨˋ [['l'], ['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄔㄨㄤˊ [['tʂʰ'], ['w'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄕˊ [['ʂ'], ['ɨ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄕˊ [['ʂ'], ['ɨ']] ㄏㄨㄣ [['x'], ['w'], ['ə', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄕㄢ [['ʂ'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄕㄢ [['ʂ'], ['a', 'n']] ['kʰ'] ['o', 'ŋ']
# ㄎㄨㄥ None ㄏㄨㄟˊ [['x'], ['w'], ['e', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄕㄢˋ [['ʂ'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄕㄥ [['ʂ'], ['ə', 'ŋ']] ㄈㄛˊ [['f'], ['ɔ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄕㄨ [['ʂ'], ['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄗˇ [['ts'], ['ɨ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄗˋ [['ts'], ['ɨ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄗㄤˋ [['ts'], ['a', 'ŋ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄗㄨㄛˋ [['ts'], ['w'], ['ɔ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄗㄨㄛˋ [['ts'], ['w'], ['ɔ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄙˋ [['s'], ['ɨ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄞˋ [['a', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄢ [['a', 'n']] ['ɕ'] ['j', 'ɛ', 'n']
# ㄒㄧㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']]  ㄦˊ [[], ['ɚ']] ㄔˋ [['tʂʰ'], ['ɨ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄧㄚ [['j'], ['a']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄧㄠˋ [['j'], ['a', 'w']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄧㄥˋ ['i', 'ŋ']
# ㄅㄠˇ [['p'], ['a', 'w']] ㄧㄥˋ ['i', 'ŋ'] ['ɕ'] ['j', 'ɛ', 'n']
# ㄒㄧㄢˋ None
# ㄅㄠˇ [['p'], ['a', 'w']] ㄨˋ [['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄨˋ [['u']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄨㄟˋ [['w'], ['e', 'j']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄨㄢˋ [['w'], ['a', 'n']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄩˋ [['y']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄩㄝˋ [['ɥ'], ['ɛ']]
# ㄅㄠˇ [['p'], ['a', 'w']] ㄩㄢˊ ['ɥ', 'ɛ', 'n'] ㄐㄩˊ [['tɕ'], ['y']]
# ㄅㄠˋ [['p'], ['a', 'w']] ['p'] ['i', 'ŋ']
# ㄅㄧㄥ None
# ㄅㄠˋ [['p'], ['a', 'w']] ['p'] ['i', 'ŋ']
# ㄅㄧㄥ None ㄐㄧ [['tɕ'], ['i']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄏㄨㄚ [['x'], ['w'], ['a']] ㄕㄨㄟˇ [['ʂ'], ['w'], ['e', 'j']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄅㄠˇ [['p'], ['a', 'w']] ㄏㄨㄞˊ [['x'], ['w'], ['a', 'j']] ㄓㄣ [['tʂ'], ['ə', 'n']]
# ㄅㄠˋ [['p'], ['a', 'w']] ['p'] ['i', 'ŋ']
# ㄅㄧㄥ None
# ㄅㄠˋ [['p'], ['a', 'w']] ['p'] ['i', 'ŋ']
# ㄅㄧㄥˋ None
# ㄅㄠˋ [['p'], ['a', 'w']] ㄅㄨˋ [['p'], ['u']] ['pʰ'] ['i', 'ŋ']
# ㄆㄧㄥˊ None
# ㄅㄠˋ [['p'], ['a', 'w']] ㄅㄨˋ [['p'], ['u']] ㄇㄠˋ [['m'], ['a', 'w']] ㄙ [['s'], ['ɨ']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄆㄣˊ ㄦ [['pʰ'], ['ə', 'n'], [], ['ɚ']] ㄓˊ [['tʂ'], ['ɨ']] ㄅㄠˋ [['p'], ['a', 'w']] ㄆㄜˊ ㄦ [['pʰ'], ['ɤ'], [], ['ɚ']] ㄓˊ [['tʂ'], ['ɨ']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄆㄧㄠˊ [['pʰ'], ['j'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄆㄨˊ [['pʰ'], ['u']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄆㄨˊ [['pʰ'], ['u']] ㄗˇ [['ts'], ['ɨ']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄆㄨˊ [['pʰ'], ['u']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄆㄨˊ [['pʰ'], ['u']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄇㄢˋ [['m'], ['a', 'n']] ㄓㄞ [['tʂ'], ['a', 'j']] ㄍㄨㄚ [['k'], ['w'], ['a']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄈㄛˊ [['f'], ['ɔ']] ㄐㄧㄠˇ [['tɕ'], ['j'], ['a', 'w']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄈㄨˋ [['f'], ['u']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄈㄨˋ [['f'], ['u']] ㄕㄨㄟˇ [['ʂ'], ['w'], ['e', 'j']] ㄓㄨㄣˇ [['tʂ'], ['w'], ['ə', 'n']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄈㄨˋ [['f'], ['u']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄉㄚˋ [['t'], ['a']] ㄗㄨˊ [['ts'], ['u']] ㄍㄢˇ [['k'], ['a', 'n']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄉㄨˊ [['t'], ['u']] ㄕㄢ [['ʂ'], ['a', 'n']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄉㄨˊ [['t'], ['u']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄉㄨˋ [['t'], ['u']]
# ㄅㄠˋ [['p'], ['a', 'w']] ㄊㄡˊ [['tʰ'], ['o', 'w']]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ccbf2119008a> in <module>
#       1 #print(toipa(zdf, 'ㄆㄧㄠ'))
# ----> 2 zhuyin2ipa(ddf,zdf)
#       3 #print(zdf.head)
#       4 #print(ddf.head)
#       5
#
# <ipython-input-3-2ed9799c4ca0> in zhuyin2ipa(ddf, zdf)
#       3         phlist = row['phone'].split('　')
#       4         for p in phlist:
# ----> 5             pipa = toipa(zdf, p)
#       6             print(p, pipa, end=" ")
#       7         print()
#
# <ipython-input-7-c778615555df> in toipa(zdf, zhuyin)
#     119                 idx = idx + 1
#     120         else:
# --> 121             IPAL.append(convertZHL(zdf, zh[idx]))
#     122             idx = idx + 1
#     123
#
# <ipython-input-7-c778615555df> in convertZHL(zdf, zh)
#      47
#      48 def convertZHL(zdf, zh):
# ---> 49     s = convertZH(zdf, zh)
#      50     if s == '':
#      51         return []
#
# <ipython-input-7-c778615555df> in convertZH(zdf, zh)
#      39     '''
#      40     #print("searching", zh)
# ---> 41     x = zdf[zdf['Zhuyin']==zh].IPA.to_string(index=False)
#      42     if x == "Series([], )":
#      43         return ''
#
# ~\Anaconda3-2019-07\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# ~\Anaconda3-2019-07\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2967         key = check_bool_indexer(self.index, key)
#    2968         indexer = key.nonzero()[0]
# -> 2969         return self._take(indexer, axis=0)
#    2970
#    2971     def _getitem_multilevel(self, key):
#
# ~\Anaconda3-2019-07\lib\site-packages\pandas\core\generic.py in _take(self, indices, axis, is_copy)
#    3357         new_data = self._data.take(indices,
#    3358                                    axis=self._get_block_manager_axis(axis),
# -> 3359                                    verify=True)
#    3360         result = self._constructor(new_data).__finalize__(self)
#    3361
#
# ~\Anaconda3-2019-07\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify, convert)
#    1348         new_labels = self.axes[axis].take(indexer)
#    1349         return self.reindex_indexer(new_axis=new_labels, indexer=indexer,
# -> 1350                                     axis=axis, allow_dups=True)
#    1351
#    1352     def merge(self, other, lsuffix='', rsuffix=''):
#
# ~\Anaconda3-2019-07\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1237         new_axes = list(self.axes)
#    1238         new_axes[axis] = new_axis
# -> 1239         return self.__class__(new_blocks, new_axes)
#    1240
#    1241     def _slice_take_blocks_ax0(self, slice_or_indexer, fill_tuple=None):
#
# ~\Anaconda3-2019-07\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     116         self._consolidate_check()
#     117
# --> 118         self._rebuild_blknos_and_blklocs()
#     119
#     120     def make_empty(self, axes=None):
#
# ~\Anaconda3-2019-07\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     196             rl = blk.mgr_locs
#     197             new_blknos[rl.indexer] = blkno
# --> 198             new_blklocs[rl.indexer] = np.arange(len(rl))
#     199
#     200         if (new_blknos == -1).any():
#
# KeyboardInterrupt:
